# %% [markdown]
# # Mobile Price Prediction
# Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("./train.csv")
print("Train dataset shape {}".format(train.shape))
train.head()
# Out:
# Train dataset shape (2000, 21)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
test = pd.read_csv("./test.csv")
print("Test dataset shape {}".format(test.shape))
test.head()
# Out:
# Test dataset shape (1000, 21)
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %%
train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# Target column => price_range

# %%
fig, ax = plt.subplots(1,1,sharex=True, figsize=(15,12))
sns.heatmap(train.corr(), fmt='.2f', cmap="YlGnBu", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Observations: \
# These factors most influence the price range of mobile
# 1) battery_power
# 2) px_height
# 3) px_width
# 4) ram

# %% [markdown]
# # Battery Power V/S Price Range

# %%
fig, ax = plt.subplots(1,2,figsize=(15,6))
sns.barplot(data=train, x='price_range', y='battery_power', ax=ax[0])
sns.lineplot(data=train, x='price_range', y='battery_power', ax=ax[1])
# Out:
# <Axes: xlabel='price_range', ylabel='battery_power'>

# %% [markdown]
# Observations:
# - The price of mobile increases with increase in battery power
# - The battery power is similar for the price range 1 and 2

# %% [markdown]
# # Bluetooth V/S Price Range

# %%
fig, ax = plt.subplots(1,2,figsize=(15,6))
sns.barplot(data=train, x='blue', y='price_range', ax=ax[0])
sns.lineplot(data=train, x='blue', y='price_range', ax=ax[1])
# Out:
# <Axes: xlabel='blue', ylabel='price_range'>

# %% [markdown]
# Observations:
# - Mobile price slightly increases with bluetooth module
